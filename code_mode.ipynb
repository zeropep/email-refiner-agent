# %%
from google.genai import types
from google.adk.agents import Agent
from google.adk.models.lite_llm import LiteLlm
from prompt import (
    TRAVEL_ADVISOR_DESCRIPTION,
    TRAVEL_ADVISOR_INSTRUCTION,
)
from google.adk.tools.tool_context import ToolContext
from google.adk.sessions import DatabaseSessionService
from google.adk.artifacts import GcsArtifactService, InMemoryArtifactService
from google.adk.runners import Runner

session_service = DatabaseSessionService(
    db_url="sqlite:///./session.db"
)

session = await session_service.create_session(
    app_name="weather_agent",
    user_id="u_123",
    state={
        "user_name": "deockpal",
    }
)



MODEL = LiteLlm(model="openai/gpt-5-nano")


async def get_weather(tool_context: ToolContext, location: str):
    """Get current weather information for a location."""
    # Dummy implementation - returns mock data
    return {
        "location": location,
        "temperature": "22°C",
        "condition": "Partly cloudy",
        "humidity": "65%",
        "wind": "12 km/h",
        "forecast": "Mild weather with occasional clouds expected throughout the day",
    }


async def get_exchange_rate(
    tool_context: ToolContext, from_currency: str, to_currency: str, amount: float
):
    """Get exchange rate between two currencies.
    Args should always be from_currency str, to_currency str, amount flot
    """
    # Dummy implementation - returns mock data
    mock_rates = {
        ("USD", "EUR"): 0.92,
        ("USD", "GBP"): 0.79,
        ("USD", "JPY"): 149.50,
        ("USD", "KRW"): 1325.00,
        ("EUR", "USD"): 1.09,
        ("EUR", "GBP"): 0.86,
        ("GBP", "USD"): 1.27,
        ("JPY", "USD"): 0.0067,
        ("KRW", "USD"): 0.00075,
    }

    rate = mock_rates.get((from_currency, to_currency), 1.0)
    converted_amount = amount * rate

    return {
        "from_currency": from_currency,
        "to_currency": to_currency,
        "amount": amount,
        "exchange_rate": rate,
        "converted_amount": converted_amount,
        "timestamp": "2024-03-15 10:30:00 UTC",
    }


async def get_local_attractions(
    tool_context: ToolContext, location: str, category: str = "all"
):
    """Get popular attractions and points of interest for a location."""
    # Dummy implementation - returns mock data
    attractions = {
        "Paris": [
            {
                "name": "Eiffel Tower",
                "type": "landmark",
                "rating": 4.8,
                "description": "Iconic iron lattice tower",
            },
            {
                "name": "Louvre Museum",
                "type": "museum",
                "rating": 4.7,
                "description": "World's largest art museum",
            },
            {
                "name": "Arc de Triomphe",
                "type": "monument",
                "rating": 4.6,
                "description": "Historic triumphal arch",
            },
            {
                "name": "Notre-Dame",
                "type": "cathedral",
                "rating": 4.5,
                "description": "Medieval Catholic cathedral",
            },
            {
                "name": "Sacré-Cœur",
                "type": "basilica",
                "rating": 4.4,
                "description": "Romano-Byzantine basilica",
            },
        ],
        "Tokyo": [
            {
                "name": "Tokyo Tower",
                "type": "landmark",
                "rating": 4.5,
                "description": "Communications and observation tower",
            },
            {
                "name": "Senso-ji",
                "type": "temple",
                "rating": 4.6,
                "description": "Ancient Buddhist temple",
            },
            {
                "name": "Shibuya Crossing",
                "type": "landmark",
                "rating": 4.4,
                "description": "Busiest pedestrian crossing",
            },
            {
                "name": "Meiji Shrine",
                "type": "shrine",
                "rating": 4.7,
                "description": "Shinto shrine dedicated to Emperor Meiji",
            },
            {
                "name": "Tokyo Skytree",
                "type": "tower",
                "rating": 4.6,
                "description": "Broadcasting and observation tower",
            },
        ],
        "default": [
            {
                "name": "City Center",
                "type": "area",
                "rating": 4.2,
                "description": "Main downtown area",
            },
            {
                "name": "Historical Museum",
                "type": "museum",
                "rating": 4.3,
                "description": "Local history and culture",
            },
            {
                "name": "Central Park",
                "type": "park",
                "rating": 4.1,
                "description": "Main public park",
            },
            {
                "name": "Old Town",
                "type": "district",
                "rating": 4.4,
                "description": "Historic district with traditional architecture",
            },
            {
                "name": "Local Market",
                "type": "market",
                "rating": 4.0,
                "description": "Traditional local marketplace",
            },
        ],
    }

    location_attractions = attractions.get(location, attractions["default"])

    if category != "all":
        location_attractions = [
            a for a in location_attractions if a["type"] == category
        ]

    return {
        "location": location,
        "category": category,
        "attractions": location_attractions,
        "total_count": len(location_attractions),
    }


travel_advisor_agent = Agent(
    name="TravelAdvisorAgent",
    description=TRAVEL_ADVISOR_DESCRIPTION,
    instruction=TRAVEL_ADVISOR_INSTRUCTION,
    tools=[
        get_weather,
        get_exchange_rate,
        get_local_attractions,
    ],
    model=MODEL,
)

runner = Runner(
    agent=travel_advisor_agent,
    session_service=session_service,
    app_name="weather_agent"
)

message = types.Content(
    role="user",
    parts=[
        types.Part(text="I'm going to Vietnam, tell me all about it."),
    ],
)

async for event in runner.run_async(user_id="u_123", session_id=session.id, new_message=message):
    if event.is_final_response():
        print(event.content)

    else:
        print(event.get_function_calls())
        print(event.get_function_responses())
# Out:
# Default value is not supported in function declaration schema for Google AI.
# Default value is not supported in function declaration schema for Google AI.
# [FunctionCall(
#   args={
#     'category': 'culture',
#     'location': 'Vietnam'
#   },
#   id='call_yk7kYD83YqZOs0KLmVWzf9Pl',
#   name='get_local_attractions'
# ), FunctionCall(
#   args={
#     'category': 'nature',
#     'location': 'Vietnam'
#   },
#   id='call_0Rf4zr1J3HOVPsKzrg1H3PhB',
#   name='get_local_attractions'
# ), FunctionCall(
#   args={
#     'category': 'beach',
#     'location': 'Vietnam'
#   },
#   id='call_9xmjv71nfgNebDiLcFkiFqNx',
#   name='get_local_attractions'
# ), FunctionCall(
#   args={
#     'category': 'food',
#     'location': 'Vietnam'
#   },
#   id='call_2TOvN2pdicN1q3tQuuesU7BI',
#   name='get_local_attractions'
# ), FunctionCall(
#   args={
#     'amount': 1,
#     'from_currency': 'USD',
#     'to_currency': 'VND'
#   },
#   id='call_Y1J7yNHRvIFybt7CBCv3OQaK',
#   name='get_exchange_rate'
# )]
# []
# []
# [FunctionResponse(
#   id='call_yk7kYD83YqZOs0KLmVWzf9Pl',
#   name='get_local_attractions',
#   response={
#     'attractions': [],
#     'category': 'culture',
#     'location': 'Vietnam',
#     'total_count': 0
#   }
# ), FunctionResponse(
#   id='call_0Rf4zr1J3HOVPsKzrg1H3PhB',
#   name='get_local_attractions',
#   response={
#     'attractions': [],
#     'category': 'nature',
#     'location': 'Vietnam',
#     'total_count': 0
#   }
# ), FunctionResponse(
#   id='call_9xmjv71nfgNebDiLcFkiFqNx',
#   name='get_local_attractions',
#   response={
#     'attractions': [],
#     'category': 'beach',
#     'location': 'Vietnam',
#     'total_count': 0
#   }
# ), FunctionResponse(
#   id='call_2TOvN2pdicN1q3tQuuesU7BI',
#   name='get_local_attractions',
#   response={
#     'attractions': [],
#     'category': 'food',
#     'location': 'Vietnam',
#     'total_count': 0
#   }
# ), FunctionResponse(
#   id='call_Y1J7yNHRvIFybt7CBCv3OQaK',
#   name='get_exchange_rate',
#   response=<dict len=6>
# )]
# parts=[Part(
#   text="""Hi deockpal! Vietnam is a vibrant, diverse country with stunning natural beauty, rich history, and fantastic food. Here’s a practical, all-around overview to help you plan.
#
# Quick snapshot
# - Capital: Hanoi (north)
# - Largest city: Ho Chi Minh City (south)
# - Language: Vietnamese (English widely spoken in tourist areas)
# - Currency: Vietnamese dong (VND)
# - Time zone: Indochina Time (UTC+7)
# - Visa: Check entry requirements for your nationality (many travelers use e-visa or visa-on-arrival options or a visa exemption for short stays, depending on passport)
#
# What to know about the climate (by region)
# - North (Hanoi, Ha Long Bay, Sapa): Four seasons. Spring and autumn are pleasant; winters (Dec-Feb) can be chilly; summers (Jun-Aug) are hot and humid with rain.
# - Central (Hue, Da Nang, Hoi An): Dry season is roughly Feb–Aug; rainy season Aug–Dec with potential typhoons.
# - South (Ho Chi Minh City, Mekong Delta): Tropically hot and humid year-round with a rainy season roughly May–Nov and a dry season Nov–Apr.
#
# Top places to see (by highlight)
# - Ha Long Bay (UNESCO): Incredible limestone karsts and emerald waters. Consider an overnight boat cruise.
# - Sapa (northern highlands): Terraced rice fields, hill tribe culture, cool climate; great for trekking.
# - Hoi An Ancient Town: Lantern-lit streets, riverside cafes, tailor shops, and nearby beaches.
# - Hue: Imperial City and royal tombs along the Perfume River.
# - Da Nang: Marble Mountains, My Khe Beach, and easy access to Ba Na Hills.
# - Phong Nha-Ke Bang National Park: Spectacular caves (Son Doong is famous; others accessible for visitors).
# - Nha Trang or Phu Quoc: Beach destinations with beautiful shorelines and snorkeling/diving.
# - Ho Chi Minh City (Saigon): War Remnants Museum, Cu Chi Tunnels, vibrant street food scene.
# - Mekong Delta (Can Tho, My Tho, Ben Tre): Floating markets and river life.
#
# Food to try (must-tries)
# - Pho (noodle soup) and pho bo/phở bò (beef) or phở gà (chicken)
# - Banh mi (baguette sandwich, often with pâté)
# - Bun cha (grilled pork with noodles, Hanoi)
# - Com tam (broken rice) and grilled meats
# - Bun bo Hue (spicy beef noodle soup)
# - Cao lau (Hoi An noodle dish)
# - Mi quang (Da Nang noodle dish)
# - Fresh seafood, especially in coastal towns
#
# Getting around (planning basics)
# - Domestic travel:
#   - Domestic flights are quick between major hubs (Hanoi, Da Nang, Ho Chi Minh City).
#   - Rail: Reunification Express covers Hanoi–Ho Chi Minh City with scenic stretches.
#   - Buses and private cars are abundant for shorter trips.
# - Connectivity and SIM: Local SIM cards are inexpensive and easy to top up.
# - Transportation tips: Watch for traffic in cities; motorbike rental is common but ride defensively. Cross streets in a steady, predictable path.
#
# Practical travel tips
# - Safety: Vietnam is generally safe for travelers. Keep valuables secure and use reputable transport/hotels.
# - Currency and costs: Vietnam is affordable for most travelers. Communicate with vendors in VND; small notes are handy in markets. Expect higher prices in tourist areas and during peak season.
# - Visa and health: Check current visa rules for your passport. Tap water isn’t recommended in most places; drink bottled water. Bring basic meds and be prepared for heat and humidity.
# - Weather readiness: Pack breathable clothing, sun protection, and a light rain jacket for sudden showers, especially in the south and central regions.
#
# Sample 10–14 day itineraries
# - Classic north–central–south loop:
#   - Hanoi (2 days) → Ha Long Bay (1–2 days cruise) → Ninh Binh or Sapa (2–3 days) → Fly to Da Nang/Hoi An (3–4 days) → Hue (1–2 days) → Fly to Ho Chi Minh City (3–4 days) → Mekong Delta day trip (1 day)
# - Beach and city blend:
#   - Ho Chi Minh City (3 days) → Mekong Delta (2 days) → Da Nang/Hoi An (4 days) → Hanoi (2 days) → Ha Long Bay (2 days)
# - Foodie and culture focus:
#   - Hanoi (3 days) → Ha Long Bay (2 days) → Hoi An (4–5 days) → Hue (2 days) → Ho Chi Minh City (3 days)
#
# Would you like me to tailor a plan to your dates, budget, and interests? I can also pull:
# - Current weather for specific cities (e.g., Hanoi, Da Nang, Ho Chi Minh City)
# - The latest USD→VND exchange rate and a few practical conversion examples
# - A personalized list of top attractions based on your interests (culture, nature, beaches, food)
#
# If you want, tell me your travel dates, preferred pace (fast vs. slow), and which region you want to focus on, and I’ll tailor a detailed itinerary and practical day-by-day plan."""
# )] role='model'
